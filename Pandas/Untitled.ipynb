# %%
import numpy as numpy
import pandas as pd

# %%
data = {"Name":['john','anna','peter','linda'],
       'age' :[20,56,85,60],
       'City':['Newyork','paris','berlin','londonn'],
       'Salary':[65000,45000,12022,55555]}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  age     City  Salary
# 0   john   20  Newyork   65000
# 1   anna   56    paris   45000
# 2  peter   85   berlin   12022
# 3  linda   60  londonn   55555

# %%
data_list = [['john',20,'newyork',65000],
        ["Anna",56,"Paris",45000],
        ["peter",80,'berlin',100000],
       ["Linda",60,"Paris",55555]]
df2 = pd.DataFrame(data_list)
coloumns =["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns=coloumns)

# %%
df2
# Out:
#     Name  Age     City  Salary
# 0   john   20  newyork   65000
# 1   Anna   56    Paris   45000
# 2  peter   80   berlin  100000
# 3  Linda   60    Paris   55555

# %%
 df2["Name"]
# Out:
# 0     john
# 1     Anna
# 2    peter
# 3    Linda
# Name: Name, dtype: object

# %%
 df2[["Name","Age"]]
# Out:
#     Name  Age
# 0   john   20
# 1   Anna   56
# 2  peter   80
# 3  Linda   60

# %% [markdown]
# creating a new column

# %%
df2["Designation"] =["Doctor","eng","Doc","eng"]

# %%
df2
# Out:
#     Name  Age     City  Salary Designation
# 0   john   20  newyork   65000      Doctor
# 1   Anna   56    Paris   45000         eng
# 2  peter   80   berlin  100000         Doc
# 3  Linda   60    Paris   55555         eng

# %% [markdown]
# Removing Column

# %%
df2.drop("Designation",axis=1)
# Out:
#     Name  Age     City  Salary
# 0   john   20  newyork   65000
# 1   Anna   56    Paris   45000
# 2  peter   80   berlin  100000
# 3  Linda   60    Paris   55555

# %%
df2.drop("Designation",axis=1,inplace= True)

# %%
df2
# Out:
#     Name  Age     City  Salary
# 0   john   20  newyork   65000
# 1   Anna   56    Paris   45000
# 2  peter   80   berlin  100000
# 3  Linda   60    Paris   55555

# %%
df2.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary
# 1   Anna   56   Paris   45000
# 2  peter   80  berlin  100000
# 3  Linda   60   Paris   55555

# %% [markdown]
# Selecting Rows

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age     City  Salary
# 0  john   20  newyork   65000
# 1  Anna   56    Paris   45000

# %%
df2.iloc[3]
# Out:
# Name      Linda
# Age          60
# City      Paris
# Salary    55555
# Name: 3, dtype: object

# %% [markdown]
# Selecting particular portion

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#       City  Salary
# 0  newyork   65000
# 1    Paris   45000

# %%
df2.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  peter   80
# 3  Linda   60

# %% [markdown]
#  Condtional Selection

# %%
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   56   Paris   45000
# 2  peter   80  berlin  100000
# 3  Linda   60   Paris   55555

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df2[{df2["Age"]>30 }& {df["City"]=="Paris"}]
#
# TypeError: unhashable type: 'Series'
