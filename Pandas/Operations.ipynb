# %%
import pandas as pd

data = {
    "Name": ["Amit", "Rahul", "Priya", "Neha", "Ravi"],
    "Age": [25, 32, 28, 35, 30],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Salary": [40000, 50000, 45000, 60000, 55000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age Department  Salary
# 0   Amit   25         IT   40000
# 1  Rahul   32         HR   50000
# 2  Priya   28         IT   45000
# 3   Neha   35    Finance   60000
# 4   Ravi   30         HR   55000

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
df.info(
    
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         5 non-null      int64
#  2   Department  5 non-null      object
#  3   Salary      5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#              Age       Salary
# count   5.000000      5.00000
# mean   30.000000  50000.00000
# std     3.807887   7905.69415
# min    25.000000  40000.00000
# 25%    28.000000  45000.00000
# 50%    30.000000  50000.00000
# 75%    32.000000  55000.00000
# max    35.000000  60000.00000

# %%
 df['Age']+8
# Out:
# 0    33
# 1    40
# 2    36
# 3    43
# 4    38
# Name: Age, dtype: int64

# %%
def square(x):
    return x**2

# %%
df['Age'].apply(square)
# Out:
# 0     625
# 1    1024
# 2     784
# 3    1225
# 4     900
# Name: Age, dtype: int64
