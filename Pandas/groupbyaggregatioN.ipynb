# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    "Name": ["Amit", "Rahul", "Neha", "Priya", "Rohit"],
    "Department": ["IT", "HR", "IT", "HR", "IT"],
    "Salary": [50000, 40000, 60000, 45000, 55000]
})

print(df)
# Out:
#     Name Department  Salary
# 0   Amit         IT   50000
# 1  Rahul         HR   40000
# 2   Neha         IT   60000
# 3  Priya         HR   45000
# 4  Rohit         IT   55000

# %%
cat = df.groupby("Department")['Salary'].sum()
cat
# Out:
# Department
# HR     85000
# IT    165000
# Name: Salary, dtype: int64

# %%
for i,v in cat:
    print(i,v)
# Out:
# HR     Name Department  Salary
# 1  Rahul         HR   40000
# 3  Priya         HR   45000
# IT     Name Department  Salary
# 0   Amit         IT   50000
# 2   Neha         IT   60000
# 4  Rohit         IT   55000

# %%
m =df['Salary'].mean()
m
# Out:
# np.float64(50000.0)

# %%
df['Salary'].agg(["sum","mean","median","min","max","count"])
# Out:
# sum       250000.0
# mean       50000.0
# median     50000.0
# min        40000.0
# max        60000.0
# count          5.0
# Name: Salary, dtype: float64
