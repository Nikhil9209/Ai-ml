# %%
import numpy as np
import pandas as pd

# %%
data ={
    'A':[1,2,1,4,5],
    'B':[1,2,3,4,5],
    'C':[1,2,3,np.nan,np.nan],
    'D':[1,np.nan,np.nan,np.nan,5]
}
df =pd.DataFrame(data)

# %%
df
# Out:
#    A  B    C    D
# 0  1  1  1.0  1.0
# 1  2  2  2.0  NaN
# 2  1  3  3.0  NaN
# 3  4  4  NaN  NaN
# 4  5  5  NaN  5.0

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2  False  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.isna().sum()
# Out:
# A    0
# B    0
# C    2
# D    3
# dtype: int64

# %%
 df.isna().any()
# Out:
# A    False
# B    False
# C     True
# D     True
# dtype: bool

# %%
df
# Out:
#    A  B    C    D
# 0  1  1  1.0  1.0
# 1  2  2  2.0  NaN
# 2  1  3  3.0  NaN
# 3  4  4  NaN  NaN
# 4  5  5  NaN  5.0

# %%
df.dropna(thresh =3)
# Out:
#    A  B    C    D
# 0  1  1  1.0  1.0
# 1  2  2  2.0  NaN
# 2  1  3  3.0  NaN
# 4  5  5  NaN  5.0

# %% [markdown]
# Filling Values

# %%
values ={'A':0,'B':100,"C":300,"D":300}

# %%
df.fillna(value=values)
# Out:
#    A  B      C      D
# 0  1  1    1.0    1.0
# 1  2  2    2.0  300.0
# 2  1  3    3.0  300.0
# 3  4  4  300.0  300.0
# 4  5  5  300.0    5.0
